# %% [markdown]
# ## Import library

# %%
pip install pyfiglet
# Out:
# Requirement already satisfied: pyfiglet in c:\users\ahmed\anaconda3\lib\site-packages (0.8.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import pickle
import pyfiglet as pfg

# %%
import tensorflow as tf
print('gpu:', tf.config.list_physical_devices('GPU'))
# Out:
# gpu: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from pyfiglet import Figlet
f = Figlet(font='slant')
print(f.renderText('AHMED YOUSEFF'))
# Out:
#     ___    __  ____  _____________
#    /   |  / / / /  |/  / ____/ __ \
#   / /| | / /_/ / /|_/ / __/ / / / /
#  / ___ |/ __  / /  / / /___/ /_/ /
# /_/  |_/_/ /_/_/  /_/_____/_____/
#
# __  ______  __  _______ __________________
# \ \/ / __ \/ / / / ___// ____/ ____/ ____/
#  \  / / / / / / /\__ \/ __/ / /_  / /_
#  / / /_/ / /_/ /___/ / /___/ __/ / __/
# /_/\____/\____//____/_____/_/   /_/

# %% [markdown]
# ## constants

# %%
IMG_DIM = 224
DATA_PATH = 'New Plant Diseases Dataset(Augmented)/'

# %% [markdown]
# ##  Read Dataset

# %%
def imread(img_path):
    img = cv2.imread(img_path)
    img = img.astype('float32')
    img = cv2.resize(img, (IMG_DIM, IMG_DIM))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

def imshow(img, figsize=(5, 5)):
    plt.figure(figsize=figsize)
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
def create_dataframe(data_path):
    df = []
    for c in os.listdir(data_path):
        class_folder = os.path.join(data_path, c)
        for f in os.listdir(class_folder):
            f_path = os.path.join(class_folder, f)
            
            df.append([f_path, c])
    return pd.DataFrame(df, columns=('filename', 'class'))

# %%
df = create_dataframe(os.path.join(DATA_PATH, 'train'))

# %%
df
# Out:
#                                                 filename  \
# 0      New Plant Diseases Dataset(Augmented)/train\Ap...
# 1      New Plant Diseases Dataset(Augmented)/train\Ap...
# 2      New Plant Diseases Dataset(Augmented)/train\Ap...
# 3      New Plant Diseases Dataset(Augmented)/train\Ap...
# 4      New Plant Diseases Dataset(Augmented)/train\Ap...
# ...                                                  ...
# 70289  New Plant Diseases Dataset(Augmented)/train\To...
# 70290  New Plant Diseases Dataset(Augmented)/train\To...
# 70291  New Plant Diseases Dataset(Augmented)/train\To...
# 70292  New Plant Diseases Dataset(Augmented)/train\To...
# 70293  New Plant Diseases Dataset(Augmented)/train\To...
#
#                                         class
# 0                          Apple___Apple_scab
# 1                          Apple___Apple_scab
# 2                          Apple___Apple_scab
# 3                          Apple___Apple_scab
# 4                          Apple___Apple_scab
# ...                                       ...
# 70289  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 70290  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 70291  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 70292  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 70293  Tomato___Tomato_Yellow_Leaf_Curl_Virus
#
# [70294 rows x 2 columns]

# %% [markdown]
# ## CLASSES LIST

# %%
diseases = os.listdir(DATA_PATH+'train')
diseases
CLASSES = sorted(diseases)
CLASSES
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn_(maize)___Common_rust_',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_(Black_Measles)',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Pepper,_bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %% [markdown]
# ## Create Data Generator

# %%
from sklearn.model_selection import train_test_split
df_train, df_val = train_test_split(df, test_size=0.30, random_state=0)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_gen = ImageDataGenerator().flow_from_dataframe(
    df_train,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    batch_size=96 ,
)

val_gen = ImageDataGenerator().flow_from_dataframe(
    df_val,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    shuffle=False,
    batch_size=96,
)
# Out:
# Found 49205 validated image filenames belonging to 38 classes.
# Found 21089 validated image filenames belonging to 38 classes.

# %%
lable =train_gen.class_indices
lable
# Out:
# {'Apple___Apple_scab': 0,
#  'Apple___Black_rot': 1,
#  'Apple___Cedar_apple_rust': 2,
#  'Apple___healthy': 3,
#  'Blueberry___healthy': 4,
#  'Cherry_(including_sour)___Powdery_mildew': 5,
#  'Cherry_(including_sour)___healthy': 6,
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7,
#  'Corn_(maize)___Common_rust_': 8,
#  'Corn_(maize)___Northern_Leaf_Blight': 9,
#  'Corn_(maize)___healthy': 10,
#  'Grape___Black_rot': 11,
#  'Grape___Esca_(Black_Measles)': 12,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13,
#  'Grape___healthy': 14,
#  'Orange___Haunglongbing_(Citrus_greening)': 15,
#  'Peach___Bacterial_spot': 16,
#  'Peach___healthy': 17,
#  'Pepper,_bell___Bacterial_spot': 18,
#  'Pepper,_bell___healthy': 19,
#  'Potato___Early_blight': 20,
#  'Potato___Late_blight': 21,
#  'Potato___healthy': 22,
#  'Raspberry___healthy': 23,
#  'Soybean___healthy': 24,
#  'Squash___Powdery_mildew': 25,
#  'Strawberry___Leaf_scorch': 26,
#  'Strawberry___healthy': 27,
#  'Tomato___Bacterial_spot': 28,
#  'Tomato___Early_blight': 29,
#  'Tomato___Late_blight': 30,
#  'Tomato___Leaf_Mold': 31,
#  'Tomato___Septoria_leaf_spot': 32,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 33,
#  'Tomato___Target_Spot': 34,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35,
#  'Tomato___Tomato_mosaic_virus': 36,
#  'Tomato___healthy': 37}

# %% [markdown]
# ## Show Sample from data

# %%
img = train_gen[0][0][0]/255.0
img.dtype
plt.imshow(img)

# %% [markdown]
# ## Model

# %% [markdown]
# ### 1. MobileNet

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.layers import GlobalAvgPool2D, Dense
from tensorflow.keras.applications.resnet import ResNet152

# %%
pretrained = ResNet152(
    input_shape=(IMG_DIM, IMG_DIM, 3),
    include_top=False
)
pretrained.trainable = False

modelN = Sequential()
modelN.add(pretrained)
modelN.add(GlobalAvgPool2D())
modelN.add(Dense(38, activation='softmax'))
modelN.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
modelN.summary()

MODEL_PATH = 'save/resnet'
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 38)                77862
#
# =================================================================
# Total params: 58,448,806
# Trainable params: 77,862
# Non-trainable params: 58,370,944
# _________________________________________________________________

# %% [markdown]
# ## Train & Save Modle

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(MODEL_PATH,
                            save_weights_only=True,
                            save_best_only=True,
                            verbose=1)
history = modelN.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/30
# 513/513 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8927
# Epoch 1: val_loss improved from inf to 0.16958, saving model to save\resnet
# 513/513 [==============================] - 2869s 6s/step - loss: 0.4298 - accuracy: 0.8927 - val_loss: 0.1696 - val_accuracy: 0.9543
# Epoch 2/30
# 513/513 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9691
# Epoch 2: val_loss improved from 0.16958 to 0.11214, saving model to save\resnet
# 513/513 [==============================] - 524s 1s/step - loss: 0.1201 - accuracy: 0.9691 - val_loss: 0.1121 - val_accuracy: 0.9695
# Epoch 3/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9806
# Epoch 3: val_loss improved from 0.11214 to 0.09278, saving model to save\resnet
# 513/513 [==============================] - 523s 1s/step - loss: 0.0775 - accuracy: 0.9806 - val_loss: 0.0928 - val_accuracy: 0.9745
# Epoch 4/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9862
# Epoch 4: val_loss improved from 0.09278 to 0.07975, saving model to save\resnet
# 513/513 [==============================] - 525s 1s/step - loss: 0.0575 - accuracy: 0.9862 - val_loss: 0.0797 - val_accuracy: 0.9780
# Epoch 5/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9900
# Epoch 5: val_loss improved from 0.07975 to 0.06867, saving model to save\resnet
# 513/513 [==============================] - 531s 1s/step - loss: 0.0434 - accuracy: 0.9900 - val_loss: 0.0687 - val_accuracy: 0.9807
# Epoch 6/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9921
# Epoch 6: val_loss improved from 0.06867 to 0.06399, saving model to save\resnet
# 513/513 [==============================] - 529s 1s/step - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.0640 - val_accuracy: 0.9813
# Epoch 7/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9944
# Epoch 7: val_loss improved from 0.06399 to 0.06310, saving model to save\resnet
# 513/513 [==============================] - 809s 2s/step - loss: 0.0281 - accuracy: 0.9944 - val_loss: 0.0631 - val_accuracy: 0.9809
# Epoch 8/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9959
# Epoch 8: val_loss did not improve from 0.06310
# 513/513 [==============================] - 519s 1s/step - loss: 0.0223 - accuracy: 0.9959 - val_loss: 0.0641 - val_accuracy: 0.9800
# Epoch 9/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9965
# Epoch 9: val_loss improved from 0.06310 to 0.06020, saving model to save\resnet
# 513/513 [==============================] - 521s 1s/step - loss: 0.0194 - accuracy: 0.9965 - val_loss: 0.0602 - val_accuracy: 0.9824
# Epoch 10/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9972
# Epoch 10: val_loss improved from 0.06020 to 0.05813, saving model to save\resnet
# 513/513 [==============================] - 521s 1s/step - loss: 0.0163 - accuracy: 0.9972 - val_loss: 0.0581 - val_accuracy: 0.9820
# Epoch 11/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9981
# Epoch 11: val_loss improved from 0.05813 to 0.05534, saving model to save\resnet
# 513/513 [==============================] - 525s 1s/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.0553 - val_accuracy: 0.9833
# Epoch 12/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9985
# Epoch 12: val_loss did not improve from 0.05534
# 513/513 [==============================] - 522s 1s/step - loss: 0.0117 - accuracy: 0.9985 - val_loss: 0.0595 - val_accuracy: 0.9811
# Epoch 13/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9985
# Epoch 13: val_loss improved from 0.05534 to 0.05244, saving model to save\resnet
# 513/513 [==============================] - 529s 1s/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.0524 - val_accuracy: 0.9838
# Epoch 14/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9991
# Epoch 14: val_loss improved from 0.05244 to 0.05136, saving model to save\resnet
# 513/513 [==============================] - 528s 1s/step - loss: 0.0085 - accuracy: 0.9991 - val_loss: 0.0514 - val_accuracy: 0.9844
# Epoch 15/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9993
# Epoch 15: val_loss improved from 0.05136 to 0.05049, saving model to save\resnet
# 513/513 [==============================] - 524s 1s/step - loss: 0.0071 - accuracy: 0.9993 - val_loss: 0.0505 - val_accuracy: 0.9847
# Epoch 16/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9989
# Epoch 16: val_loss did not improve from 0.05049
# 513/513 [==============================] - 518s 1s/step - loss: 0.0076 - accuracy: 0.9989 - val_loss: 0.0627 - val_accuracy: 0.9809
# Epoch 17/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9993
# Epoch 17: val_loss did not improve from 0.05049
# 513/513 [==============================] - 518s 1s/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0505 - val_accuracy: 0.9850
# Epoch 18/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9996
# Epoch 18: val_loss did not improve from 0.05049
# 513/513 [==============================] - 519s 1s/step - loss: 0.0048 - accuracy: 0.9996 - val_loss: 0.0514 - val_accuracy: 0.9837
# Epoch 19/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9994
# Epoch 19: val_loss did not improve from 0.05049
# 513/513 [==============================] - 522s 1s/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.0547 - val_accuracy: 0.9834
# Epoch 20/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9995
# Epoch 20: val_loss did not improve from 0.05049
# 513/513 [==============================] - 522s 1s/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.0508 - val_accuracy: 0.9852
# Epoch 21/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9998
# Epoch 21: val_loss improved from 0.05049 to 0.04924, saving model to save\resnet
# 513/513 [==============================] - 555s 1s/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0492 - val_accuracy: 0.9852
# Epoch 22/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9998
# Epoch 22: val_loss improved from 0.04924 to 0.04919, saving model to save\resnet
# 513/513 [==============================] - 529s 1s/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0492 - val_accuracy: 0.9858
# Epoch 23/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9999
# Epoch 23: val_loss did not improve from 0.04919
# 513/513 [==============================] - 518s 1s/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0603 - val_accuracy: 0.9832
# Epoch 24/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9979
# Epoch 24: val_loss did not improve from 0.04919
# 513/513 [==============================] - 517s 1s/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0586 - val_accuracy: 0.9844
# Epoch 25/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9998
# Epoch 25: val_loss did not improve from 0.04919
# 513/513 [==============================] - 518s 1s/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0536 - val_accuracy: 0.9848
# Epoch 26/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9999
# Epoch 26: val_loss did not improve from 0.04919
# 513/513 [==============================] - 522s 1s/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.0522 - val_accuracy: 0.9848
# Epoch 27/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9999
# Epoch 27: val_loss did not improve from 0.04919
# 513/513 [==============================] - 521s 1s/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.0589 - val_accuracy: 0.9829
# Epoch 28/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995
# Epoch 28: val_loss did not improve from 0.04919
# 513/513 [==============================] - 539s 1s/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0527 - val_accuracy: 0.9848
# Epoch 29/30
# 513/513 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.04919
# 513/513 [==============================] - 519s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9860
# Epoch 30/30
# 513/513 [==============================] - ETA: 0s - loss: 9.8094e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.04919
# 513/513 [==============================] - 517s 1s/step - loss: 9.8094e-04 - accuracy: 1.0000 - val_loss: 0.0505 - val_accuracy: 0.9862

# %% [markdown]
# ## Plot Modle History

# %%
hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['loss', 'val_loss'], figsize=(8, 5))
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.grid(axis='both')
plt.xticks(np.arange(0, 30, 3))
plt.show()

# %%
hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['accuracy', 'val_accuracy'], figsize=(8, 5))
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Training and Validation Accuracy')
plt.grid(axis='both')
plt.xticks(np.arange(0, 30, 3))
plt.yticks(np.arange(0.5, 1.01, 0.05))
plt.show()

# %% [markdown]
# ## Read test data

# %%
pwd
# Out:
# 'd:\\datascince\\Plant Diseases'

# %%
df_test = create_dataframe(os.path.join(DATA_PATH, 'test'))

# %%
test_gen = ImageDataGenerator().flow_from_dataframe(
    df_test,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    shuffle=False,
    batch_size=128,
)
# Out:
# Found 17570 validated image filenames belonging to 38 classes.

# %% [markdown]
# ## Test Modle & Loading best weights

# %%
print(MODEL_PATH)
model.load_weights(MODEL_PATH)
# Out:
# save/resnet

# %%
model.evaluate(test_gen)
# Out:
# 138/138 [==============================] - 133s 922ms/step - loss: 0.0510 - accuracy: 0.9844
# [0.051035936921834946, 0.9844052195549011]

# %% [markdown]
# # Analyzing & Test model

# %%
pwd
# Out:
# 'd:\\datascince\\Plant Diseases'

# %%
dft=create_dataframe(os.path.join('testd'))

# %%
dft
# Out:
#                                  filename class
# 0                      testd\test\aaa.JPG  test
# 1                     testd\test\aaaa.JPG  test
# 2          testd\test\AppleCedarRust1.JPG  test
# 3          testd\test\AppleCedarRust2.JPG  test
# 4          testd\test\AppleCedarRust3.JPG  test
# 5          testd\test\AppleCedarRust4.JPG  test
# 6               testd\test\AppleScab1.JPG  test
# 7               testd\test\AppleScab2.JPG  test
# 8               testd\test\AppleScab3.JPG  test
# 9          testd\test\CornCommonRust1.JPG  test
# 10         testd\test\CornCommonRust2.JPG  test
# 11         testd\test\CornCommonRust3.JPG  test
# 12      testd\test\PotatoEarlyBlight1.JPG  test
# 13      testd\test\PotatoEarlyBlight2.JPG  test
# 14      testd\test\PotatoEarlyBlight3.JPG  test
# 15      testd\test\PotatoEarlyBlight4.JPG  test
# 16      testd\test\PotatoEarlyBlight5.JPG  test
# 17          testd\test\PotatoHealthy1.JPG  test
# 18          testd\test\PotatoHealthy2.JPG  test
# 19      testd\test\TomatoEarlyBlight1.JPG  test
# 20      testd\test\TomatoEarlyBlight2.JPG  test
# 21      testd\test\TomatoEarlyBlight3.JPG  test
# 22      testd\test\TomatoEarlyBlight4.JPG  test
# 23      testd\test\TomatoEarlyBlight5.JPG  test
# 24      testd\test\TomatoEarlyBlight6.JPG  test
# 25          testd\test\TomatoHealthy1.JPG  test
# 26          testd\test\TomatoHealthy2.JPG  test
# 27          testd\test\TomatoHealthy3.JPG  test
# 28          testd\test\TomatoHealthy4.JPG  test
# 29  testd\test\TomatoYellowCurlVirus1.JPG  test
# 30  testd\test\TomatoYellowCurlVirus2.JPG  test
# 31  testd\test\TomatoYellowCurlVirus3.JPG  test
# 32  testd\test\TomatoYellowCurlVirus4.JPG  test
# 33  testd\test\TomatoYellowCurlVirus5.JPG  test
# 34  testd\test\TomatoYellowCurlVirus6.JPG  test

# %%
dft_gen = ImageDataGenerator().flow_from_dataframe(
    dft,
    target_size=(IMG_DIM, IMG_DIM),
)
# Out:
# Found 35 validated image filenames belonging to 1 classes.

# %% [markdown]
# ### Saliency maps

# %%
import tensorflow as tf

def saliency_map(img):
    
    plt.imshow(img/255.0)
    plt.show()
   


    x = tf.Variable(np.expand_dims(img, 0), dtype='float32')

    with tf.GradientTape() as tape:
        result = model(x)
        y = result[:, np.argmax(result)]
        grads = tape.gradient(y, x)

    grads_2d = grads.numpy()[0].max(axis=2)
    grads_2d_norm = (grads_2d - grads_2d.min())/(grads_2d.max() - grads_2d.min())

    grads_2d_uint8 = (grads_2d_norm*255.0).astype('uint8')
    _, grads_2d_bin = cv2.threshold(grads_2d_uint8, 0, 255, cv2.THRESH_OTSU)
    plt.imshow(grads_2d_bin, cmap='gray')
    plt.show()
    
    print(CLASSES[np.argmax(result)])

# %%
import tensorflow as tf

def per_map(img):
    
    plt.imshow(img)
    plt.show()
   


    x = tf.Variable(np.expand_dims(img, 0), dtype='float32')

    with tf.GradientTape() as tape:
        result = model(x)
        y = result[:, np.argmax(result)]
        grads = tape.gradient(y, x)

    
    print(CLASSES[np.argmax(result)])

# %%
img_path = 'testd/test/TomatoEarlyBlight2.JPG'
img2 = imread(img_path)
imshow(img2/255.0)
img2.shape
# Out:
# (224, 224, 3)

# %%
img2.shape
# Out:
# (224, 224, 3)

# %%
saliency_map(img2)
# Out:
# Tomato___Early_blight

# %% [markdown]
# ## Save in TFlite format

# %%
TF_LITE_MODEL_FILE_NAME = "plant Diseases(98.4).tflite"

# %%
import tensorflow as tf

tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tf_lite_converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 155). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\ahmed\AppData\Local\Temp\tmpk9luvy4m\assets
# INFO:tensorflow:Assets written to: C:\Users\ahmed\AppData\Local\Temp\tmpk9luvy4m\assets

# %%
tflite_model_name = TF_LITE_MODEL_FILE_NAME
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 232700844

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
convert_bytes(get_file_size(TF_LITE_MODEL_FILE_NAME), "KB")
# Out:
# File size: 227246.918 Kilobytes
