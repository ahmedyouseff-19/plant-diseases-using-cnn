# %% [markdown]
# ## Import library

# %%
import cv2
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## constants

# %%
# constants
IMG_DIM = 224
DATA_PATH = "../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/"

# %% [markdown]
# ##  Read Dataset

# %%
def imread(img_path):
    img = cv2.imread(img_path)
    img = img.astype('float32')
    img = cv2.resize(img, (IMG_DIM, IMG_DIM))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

def imshow(img, figsize=(5, 5)):
    plt.figure(figsize=figsize)
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
def create_dataframe(data_path):
    df = []
    for c in os.listdir(data_path):
        class_folder = os.path.join(data_path, c)
        for f in os.listdir(class_folder):
            f_path = os.path.join(class_folder, f)
            
            df.append([f_path, c])
    return pd.DataFrame(df, columns=('filename', 'class'))

# %%
df = create_dataframe(os.path.join(DATA_PATH, 'train'))

# %%
df
# Out:
#                                                 filename  \
# 0      ../input/new-plant-diseases-dataset/New Plant ...
# 1      ../input/new-plant-diseases-dataset/New Plant ...
# 2      ../input/new-plant-diseases-dataset/New Plant ...
# 3      ../input/new-plant-diseases-dataset/New Plant ...
# 4      ../input/new-plant-diseases-dataset/New Plant ...
# ...                                                  ...
# 70290  ../input/new-plant-diseases-dataset/New Plant ...
# 70291  ../input/new-plant-diseases-dataset/New Plant ...
# 70292  ../input/new-plant-diseases-dataset/New Plant ...
# 70293  ../input/new-plant-diseases-dataset/New Plant ...
# 70294  ../input/new-plant-diseases-dataset/New Plant ...
#
#                         class
# 0        Tomato___Late_blight
# 1        Tomato___Late_blight
# 2        Tomato___Late_blight
# 3        Tomato___Late_blight
# 4        Tomato___Late_blight
# ...                       ...
# 70290  Corn_(maize)___healthy
# 70291  Corn_(maize)___healthy
# 70292  Corn_(maize)___healthy
# 70293  Corn_(maize)___healthy
# 70294  Corn_(maize)___healthy
#
# [70295 rows x 2 columns]

# %% [markdown]
# ## CLASSES LIST

# %%
diseases = os.listdir(DATA_PATH+'train')
diseases
CLASSES = sorted(diseases)
CLASSES
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn_(maize)___Common_rust_',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_(Black_Measles)',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Pepper,_bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %% [markdown]
# ## Create Data Generator

# %%
from sklearn.model_selection import train_test_split
df_train, df_val = train_test_split(df, test_size=0.30, random_state=0)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_gen = ImageDataGenerator().flow_from_dataframe(
    df_train,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    batch_size=128,
)

val_gen = ImageDataGenerator().flow_from_dataframe(
    df_val,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    shuffle=False,
    batch_size=128,
)
# Out:
# Found 49206 validated image filenames belonging to 38 classes.
# Found 21089 validated image filenames belonging to 38 classes.

# %%
lable =train_gen.class_indices
lable
# Out:
# {'Apple___Apple_scab': 0,
#  'Apple___Black_rot': 1,
#  'Apple___Cedar_apple_rust': 2,
#  'Apple___healthy': 3,
#  'Blueberry___healthy': 4,
#  'Cherry_(including_sour)___Powdery_mildew': 5,
#  'Cherry_(including_sour)___healthy': 6,
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7,
#  'Corn_(maize)___Common_rust_': 8,
#  'Corn_(maize)___Northern_Leaf_Blight': 9,
#  'Corn_(maize)___healthy': 10,
#  'Grape___Black_rot': 11,
#  'Grape___Esca_(Black_Measles)': 12,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13,
#  'Grape___healthy': 14,
#  'Orange___Haunglongbing_(Citrus_greening)': 15,
#  'Peach___Bacterial_spot': 16,
#  'Peach___healthy': 17,
#  'Pepper,_bell___Bacterial_spot': 18,
#  'Pepper,_bell___healthy': 19,
#  'Potato___Early_blight': 20,
#  'Potato___Late_blight': 21,
#  'Potato___healthy': 22,
#  'Raspberry___healthy': 23,
#  'Soybean___healthy': 24,
#  'Squash___Powdery_mildew': 25,
#  'Strawberry___Leaf_scorch': 26,
#  'Strawberry___healthy': 27,
#  'Tomato___Bacterial_spot': 28,
#  'Tomato___Early_blight': 29,
#  'Tomato___Late_blight': 30,
#  'Tomato___Leaf_Mold': 31,
#  'Tomato___Septoria_leaf_spot': 32,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 33,
#  'Tomato___Target_Spot': 34,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35,
#  'Tomato___Tomato_mosaic_virus': 36,
#  'Tomato___healthy': 37}

# %% [markdown]
# ## Show Sample from data

# %%
img = train_gen[0][0][2]/255.0
img.dtype
plt.imshow(img)

# %% [markdown]
# ## Build CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAvgPool2D, Dense, Flatten,Dropout
model= Sequential()

model.add(Conv2D(64, 3, input_shape=(IMG_DIM, IMG_DIM, 3), activation='relu'))
model.add(MaxPool2D(2))
model.add(Conv2D(96, 3, activation='relu'))
model.add(MaxPool2D(2))
model.add(Conv2D(128, 3, activation='relu'))
model.add(MaxPool2D(2))
model.add(Conv2D(256, 3, activation='relu'))
model.add(MaxPool2D(2))
model.add(Conv2D(512, 3, activation='relu'))
model.add(MaxPool2D(2))
model.add(Flatten())
#Fully C L
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))


model.add(Dense(38, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
MODEL_PATH = 'saved-models/pdcnn3'
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 96)      55392
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 96)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       110720
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 256)               3277056
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 38)                9766
#
# =================================================================
# Total params: 4,930,054
# Trainable params: 4,930,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train & Save Modle

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(MODEL_PATH,
                            save_weights_only=True,
                            save_best_only=True,
                            verbose=1)
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=13,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/13
# 385/385 [==============================] - ETA: 0s - loss: 2.7199 - accuracy: 0.2997
# Epoch 1: val_loss improved from inf to 1.15965, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 503s 1s/step - loss: 2.7199 - accuracy: 0.2997 - val_loss: 1.1596 - val_accuracy: 0.6588
# Epoch 2/13
# 385/385 [==============================] - ETA: 0s - loss: 1.1258 - accuracy: 0.6641
# Epoch 2: val_loss improved from 1.15965 to 0.56493, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 238s 617ms/step - loss: 1.1258 - accuracy: 0.6641 - val_loss: 0.5649 - val_accuracy: 0.8260
# Epoch 3/13
# 385/385 [==============================] - ETA: 0s - loss: 0.7338 - accuracy: 0.7757
# Epoch 3: val_loss improved from 0.56493 to 0.37100, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 238s 618ms/step - loss: 0.7338 - accuracy: 0.7757 - val_loss: 0.3710 - val_accuracy: 0.8837
# Epoch 4/13
# 385/385 [==============================] - ETA: 0s - loss: 0.5569 - accuracy: 0.8267
# Epoch 4: val_loss improved from 0.37100 to 0.34129, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 237s 617ms/step - loss: 0.5569 - accuracy: 0.8267 - val_loss: 0.3413 - val_accuracy: 0.8951
# Epoch 5/13
# 385/385 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.8613
# Epoch 5: val_loss improved from 0.34129 to 0.27419, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 238s 618ms/step - loss: 0.4394 - accuracy: 0.8613 - val_loss: 0.2742 - val_accuracy: 0.9164
# Epoch 6/13
# 385/385 [==============================] - ETA: 0s - loss: 0.3847 - accuracy: 0.8802
# Epoch 6: val_loss improved from 0.27419 to 0.22342, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 237s 617ms/step - loss: 0.3847 - accuracy: 0.8802 - val_loss: 0.2234 - val_accuracy: 0.9320
# Epoch 7/13
# 385/385 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.8959
# Epoch 7: val_loss did not improve from 0.22342
# 385/385 [==============================] - 238s 618ms/step - loss: 0.3245 - accuracy: 0.8959 - val_loss: 0.2957 - val_accuracy: 0.9096
# Epoch 8/13
# 385/385 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.9038
# Epoch 8: val_loss did not improve from 0.22342
# 385/385 [==============================] - 240s 623ms/step - loss: 0.2996 - accuracy: 0.9038 - val_loss: 0.2395 - val_accuracy: 0.9257
# Epoch 9/13
# 385/385 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9184
# Epoch 9: val_loss improved from 0.22342 to 0.20805, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 238s 618ms/step - loss: 0.2504 - accuracy: 0.9184 - val_loss: 0.2081 - val_accuracy: 0.9357
# Epoch 10/13
# 385/385 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9265
# Epoch 10: val_loss improved from 0.20805 to 0.20471, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 237s 615ms/step - loss: 0.2290 - accuracy: 0.9265 - val_loss: 0.2047 - val_accuracy: 0.9385
# Epoch 11/13
# 385/385 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9270
# Epoch 11: val_loss did not improve from 0.20471
# 385/385 [==============================] - 236s 614ms/step - loss: 0.2235 - accuracy: 0.9270 - val_loss: 0.2137 - val_accuracy: 0.9366
# Epoch 12/13
# 385/385 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9395
# Epoch 12: val_loss did not improve from 0.20471
# 385/385 [==============================] - 238s 620ms/step - loss: 0.1876 - accuracy: 0.9395 - val_loss: 0.2086 - val_accuracy: 0.9401
# Epoch 13/13
# 385/385 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9403
# Epoch 13: val_loss improved from 0.20471 to 0.19055, saving model to saved-models/pdcnn2
# 385/385 [==============================] - 239s 621ms/step - loss: 0.1852 - accuracy: 0.9403 - val_loss: 0.1906 - val_accuracy: 0.9458

# %% [markdown]
# ## Plot Modle History

# %%
hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['loss', 'val_loss'], figsize=(8, 5))
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.grid(axis='both')
plt.xticks(np.arange(0, 20, 2))
plt.show()

# %%
hist_df = pd.DataFrame(history.history)
hist_df.plot(y=['accuracy', 'val_accuracy'], figsize=(8, 5))
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Training and Validation Accuracy')
plt.grid(axis='both')
plt.xticks(np.arange(0, 20, 2))
plt.yticks(np.arange(0.5, 1.01, 0.05))
plt.show()

# %% [markdown]
# ## Read test data

# %%
df_test = create_dataframe(os.path.join(DATA_PATH, 'valid'))

# %%
test_gen = ImageDataGenerator().flow_from_dataframe(
    df_test,
    target_size=(IMG_DIM, IMG_DIM),
    classes=CLASSES,
    shuffle=False,
    batch_size=128,
)
# Out:
# Found 17572 validated image filenames belonging to 38 classes.

# %% [markdown]
# ## Test Modle & Loading best weights

# %%
print(MODEL_PATH)
model.load_weights(MODEL_PATH)
model.evaluate(test_gen)
# Out:
# saved-models/pdcnn2
# 138/138 [==============================] - 132s 959ms/step - loss: 0.2017 - accuracy: 0.9449
# [0.20169119536876678, 0.9448554515838623]

# %% [markdown]
# # Analyzing & Test model

# %%
dft=create_dataframe(os.path.join("/kaggle/input/new-plant-diseases-dataset/test/"))

# %%
dft
# Out:
#                                              filename class
# 0   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 1   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 2   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 3   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 4   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 5   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 6   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 7   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 8   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 9   /kaggle/input/new-plant-diseases-dataset/test/...  test
# 10  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 11  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 12  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 13  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 14  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 15  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 16  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 17  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 18  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 19  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 20  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 21  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 22  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 23  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 24  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 25  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 26  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 27  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 28  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 29  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 30  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 31  /kaggle/input/new-plant-diseases-dataset/test/...  test
# 32  /kaggle/input/new-plant-diseases-dataset/test/...  test

# %%
dft_gen = ImageDataGenerator().flow_from_dataframe(
    dft,
    target_size=(IMG_DIM, IMG_DIM),
)
# Out:
# Found 33 validated image filenames belonging to 1 classes.

# %% [markdown]
# ### Saliency maps

# %%
import tensorflow as tf

def saliency_map(img):
    
    plt.imshow(img/255.0)
    plt.show()
   


    x = tf.Variable(np.expand_dims(img, 0), dtype='float32')

    with tf.GradientTape() as tape:
        result = model(x)
        y = result[:, np.argmax(result)]
        grads = tape.gradient(y, x)

    grads_2d = grads.numpy()[0].max(axis=2)
    grads_2d_norm = (grads_2d - grads_2d.min())/(grads_2d.max() - grads_2d.min())

    grads_2d_uint8 = (grads_2d_norm*255.0).astype('uint8')
    _, grads_2d_bin = cv2.threshold(grads_2d_uint8, 0, 255, cv2.THRESH_OTSU)
    plt.imshow(grads_2d_bin, cmap='gray')
    plt.show()
    
    print(CLASSES[np.argmax(result)])

# %%
img_path = '//kaggle/input/new-plant-diseases-dataset/test/test/TomatoHealthy3.JPG'
img3 = imread(img_path)
imshow(img3/255.0)
img3.shape
# Out:
# (224, 224, 3)

# %%
img2 = dft_gen[0][0][5]

# %%
saliency_map(img3)
# Out:
# Tomato___healthy

# %%
y_r=model.predict(np.expand_dims(img3, 0))
CLASSES[np.argmax(y_r)]
# Out:
# 1/1 [==============================] - 0s 178ms/step
# 'Tomato___healthy'

# %% [markdown]
# ## Save in TFlite format

# %%
TF_LITE_MODEL_FILE_NAME = "plant-Diseases3.tflite"

# %%
import tensorflow as tf

tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tf_lite_converter.convert()

# %%
tflite_model_name = TF_LITE_MODEL_FILE_NAME
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# 19725644

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
convert_bytes(get_file_size(TF_LITE_MODEL_FILE_NAME), "KB")
